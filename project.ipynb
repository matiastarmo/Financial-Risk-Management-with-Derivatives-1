# %%
import importlib.util
import pip

def check_and_install(package):
    try:
        spec = importlib.util.find_spec(package)
        if spec is None:
            print(f"Installing {package}...")
            pip.main(['install', package])
    except Exception as e:
        print(f"Error installing {package}: {e}")

packages = ['pyfinance', 'mpl_toolkits', 'pyarrow', 'plotly']

for package in packages:
    check_and_install(package)
# Out:
# Installing pyfinance...
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# Collecting pyfinance
#   Downloading pyfinance-1.3.0-py3-none-any.whl.metadata (16 kB)
# Collecting beautifulsoup4 (from pyfinance)
#   Downloading beautifulsoup4-4.14.2-py3-none-any.whl.metadata (3.8 kB)
# Collecting matplotlib (from pyfinance)
#   Downloading matplotlib-3.10.7-cp314-cp314-win_amd64.whl.metadata (11 kB)
# Collecting numpy (from pyfinance)
#   Downloading numpy-2.3.4-cp314-cp314-win_amd64.whl.metadata (60 kB)
# Collecting pandas-datareader (from pyfinance)
#   Downloading pandas_datareader-0.10.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting pandas>=0.20 (from pyfinance)
#   Downloading pandas-2.3.3-cp314-cp314-win_amd64.whl.metadata (19 kB)
# Collecting requests (from pyfinance)
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting scipy (from pyfinance)
#   Downloading scipy-1.16.3-cp314-cp314-win_amd64.whl.metadata (60 kB)
# Collecting seaborn (from pyfinance)
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting scikit-learn (from pyfinance)
#   Downloading scikit_learn-1.7.2-cp314-cp314-win_amd64.whl.metadata (11 kB)
# Collecting statsmodels (from pyfinance)
#   Downloading statsmodels-0.14.5-cp314-cp314-win_amd64.whl.metadata (9.8 kB)
# Collecting xlrd (from pyfinance)
#   Downloading xlrd-2.0.2-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting xmltodict (from pyfinance)
#   Downloading xmltodict-1.0.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\projekti\financial-risk-management-with-derivatives-1\.venv\lib\site-packages (from pandas>=0.20->pyfinance) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas>=0.20->pyfinance)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas>=0.20->pyfinance)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\projekti\financial-risk-management-with-derivatives-1\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.20->pyfinance) (1.17.0)
# Collecting soupsieve>1.2 (from beautifulsoup4->pyfinance)
#   Downloading soupsieve-2.8-py3-none-any.whl.metadata (4.6 kB)
# Collecting typing-extensions>=4.0.0 (from beautifulsoup4->pyfinance)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting contourpy>=1.0.1 (from matplotlib->pyfinance)
#   Downloading contourpy-1.3.3-cp314-cp314-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib->pyfinance)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->pyfinance)
#   Downloading fonttools-4.60.1-cp314-cp314-win_amd64.whl.metadata (114 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib->pyfinance)
#   Downloading kiwisolver-1.4.9-cp314-cp314-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: packaging>=20.0 in c:\projekti\financial-risk-management-with-derivatives-1\.venv\lib\site-packages (from matplotlib->pyfinance) (25.0)
# Collecting pillow>=8 (from matplotlib->pyfinance)
#   Downloading pillow-12.0.0-cp314-cp314-win_amd64.whl.metadata (9.0 kB)
# Collecting pyparsing>=3 (from matplotlib->pyfinance)
#   Downloading pyparsing-3.2.5-py3-none-any.whl.metadata (5.0 kB)
# Collecting lxml (from pandas-datareader->pyfinance)
#   Downloading lxml-6.0.2-cp314-cp314-win_amd64.whl.metadata (3.7 kB)
# Collecting charset_normalizer<4,>=2 (from requests->pyfinance)
#   Downloading charset_normalizer-3.4.4-cp314-cp314-win_amd64.whl.metadata (38 kB)
# Collecting idna<4,>=2.5 (from requests->pyfinance)
#   Downloading idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting urllib3<3,>=1.21.1 (from requests->pyfinance)
#   Downloading urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests->pyfinance)
#   Downloading certifi-2025.11.12-py3-none-any.whl.metadata (2.5 kB)
# Collecting joblib>=1.2.0 (from scikit-learn->pyfinance)
#   Downloading joblib-1.5.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn->pyfinance)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting patsy>=0.5.6 (from statsmodels->pyfinance)
#   Downloading patsy-1.0.2-py2.py3-none-any.whl.metadata (3.6 kB)
# Downloading pyfinance-1.3.0-py3-none-any.whl (57 kB)
# Downloading pandas-2.3.3-cp314-cp314-win_amd64.whl (11.1 MB)
# c:\Projekti\Financial-Risk-Management-with-Derivatives-1\.venv\Lib\site-packages\pip\_vendor\rich\live.py:256:
# UserWarning: install "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Downloading numpy-2.3.4-cp314-cp314-win_amd64.whl (12.9 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Downloading beautifulsoup4-4.14.2-py3-none-any.whl (106 kB)
# Downloading soupsieve-2.8-py3-none-any.whl (36 kB)
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading matplotlib-3.10.7-cp314-cp314-win_amd64.whl (8.3 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Downloading contourpy-1.3.3-cp314-cp314-win_amd64.whl (232 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.60.1-cp314-cp314-win_amd64.whl (2.3 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Downloading kiwisolver-1.4.9-cp314-cp314-win_amd64.whl (75 kB)
# Downloading pillow-12.0.0-cp314-cp314-win_amd64.whl (7.1 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Downloading pyparsing-3.2.5-py3-none-any.whl (113 kB)
# Downloading pandas_datareader-0.10.0-py3-none-any.whl (109 kB)
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.4-cp314-cp314-win_amd64.whl (107 kB)
# Downloading idna-3.11-py3-none-any.whl (71 kB)
# Downloading urllib3-2.5.0-py3-none-any.whl (129 kB)
# Downloading certifi-2025.11.12-py3-none-any.whl (159 kB)
# Downloading lxml-6.0.2-cp314-cp314-win_amd64.whl (4.1 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Downloading scikit_learn-1.7.2-cp314-cp314-win_amd64.whl (8.8 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Downloading joblib-1.5.2-py3-none-any.whl (308 kB)
# Downloading scipy-1.16.3-cp314-cp314-win_amd64.whl (39.4 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading statsmodels-0.14.5-cp314-cp314-win_amd64.whl (9.6 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Downloading patsy-1.0.2-py2.py3-none-any.whl (233 kB)
# Downloading xlrd-2.0.2-py2.py3-none-any.whl (96 kB)
# Downloading xmltodict-1.0.2-py3-none-any.whl (13 kB)
# Installing collected packages: pytz, xmltodict, xlrd, urllib3, tzdata, typing-extensions, threadpoolctl, soupsieve, pyparsing, pillow, numpy, lxml, kiwisolver, joblib, idna, fonttools, cycler, charset_normalizer, certifi, scipy, requests, patsy, pandas, contourpy, beautifulsoup4, statsmodels, scikit-learn, pandas-datareader, matplotlib, seaborn, pyfinance
# c:\Projekti\Financial-Risk-Management-with-Derivatives-1\.venv\Lib\site-packages\pip\_vendor\rich\live.py:256: UserWarning: install "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# c:\Projekti\Financial-Risk-Management-with-Derivatives-1\.venv\Lib\site-packages\pip\_vendor\rich\live.py:256: UserWarning: install "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# c:\Projekti\Financial-Risk-Management-with-Derivatives-1\.venv\Lib\site-packages\pip\_vendor\rich\live.py:256: UserWarning: install "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# c:\Projekti\Financial-Risk-Management-with-Derivatives-1\.venv\Lib\site-packages\pip\_vendor\rich\live.py:256: UserWarning: install "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# c:\Projekti\Financial-Risk-Management-with-Derivatives-1\.venv\Lib\site-packages\pip\_vendor\rich\live.py:256: UserWarning: install "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# c:\Projekti\Financial-Risk-Management-with-Derivatives-1\.venv\Lib\site-packages\pip\_vendor\rich\live.py:256: UserWarning: install "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# c:\Projekti\Financial-Risk-Management-with-Derivatives-1\.venv\Lib\site-packages\pip\_vendor\rich\live.py:256: UserWarning: install "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# c:\Projekti\Financial-Risk-Management-with-Derivatives-1\.venv\Lib\site-packages\pip\_vendor\rich\live.py:256: UserWarning: install "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# c:\Projekti\Financial-Risk-Management-with-Derivatives-1\.venv\Lib\site-packages\pip\_vendor\rich\live.py:256: UserWarning: install "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# c:\Projekti\Financial-Risk-Management-with-Derivatives-1\.venv\Lib\site-packages\pip\_vendor\rich\live.py:256: UserWarning: install "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# c:\Projekti\Financial-Risk-Management-with-Derivatives-1\.venv\Lib\site-packages\pip\_vendor\rich\live.py:256: UserWarning: install "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# c:\Projekti\Financial-Risk-Management-with-Derivatives-1\.venv\Lib\site-packages\pip\_vendor\rich\live.py:256: UserWarning: install "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# c:\Projekti\Financial-Risk-Management-with-Derivatives-1\.venv\Lib\site-packages\pip\_vendor\rich\live.py:256: UserWarning: install "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# c:\Projekti\Financial-Risk-Management-with-Derivatives-1\.venv\Lib\site-packages\pip\_vendor\rich\live.py:256: UserWarning: install "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Successfully installed beautifulsoup4-4.14.2 certifi-2025.11.12 charset_normalizer-3.4.4 contourpy-1.3.3 cycler-0.12.1 fonttools-4.60.1 idna-3.11 joblib-1.5.2 kiwisolver-1.4.9 lxml-6.0.2 matplotlib-3.10.7 numpy-2.3.4 pandas-2.3.3 pandas-datareader-0.10.0 patsy-1.0.2 pillow-12.0.0 pyfinance-1.3.0 pyparsing-3.2.5 pytz-2025.2 requests-2.32.5 scikit-learn-1.7.2 scipy-1.16.3 seaborn-0.13.2 soupsieve-2.8 statsmodels-0.14.5 threadpoolctl-3.6.0 typing-extensions-4.15.0 tzdata-2025.2 urllib3-2.5.0 xlrd-2.0.2 xmltodict-1.0.2
# Installing pyarrow...
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# Collecting pyarrow
#   Downloading pyarrow-22.0.0-cp314-cp314-win_amd64.whl.metadata (3.3 kB)
# Downloading pyarrow-22.0.0-cp314-cp314-win_amd64.whl (28.8 MB)
# c:\Projekti\Financial-Risk-Management-with-Derivatives-1\.venv\Lib\site-packages\pip\_vendor\rich\live.py:256:
# UserWarning: install "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Installing collected packages: pyarrow
# Successfully installed pyarrow-22.0.0
# Installing plotly...
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# Collecting plotly
#   Downloading plotly-6.4.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting narwhals>=1.15.1 (from plotly)
#   Downloading narwhals-2.11.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging in c:\projekti\financial-risk-management-with-derivatives-1\.venv\lib\site-packages (from plotly) (25.0)
# Downloading plotly-6.4.0-py3-none-any.whl (9.9 MB)
# c:\Projekti\Financial-Risk-Management-with-Derivatives-1\.venv\Lib\site-packages\pip\_vendor\rich\live.py:256:
# UserWarning: install "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Downloading narwhals-2.11.0-py3-none-any.whl (423 kB)
# Installing collected packages: narwhals, plotly
# c:\Projekti\Financial-Risk-Management-with-Derivatives-1\.venv\Lib\site-packages\pip\_vendor\rich\live.py:256: UserWarning: install "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Successfully installed narwhals-2.11.0 plotly-6.4.0

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm, lognorm
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D
#from datar import f
#from datar.dplyr import mutate, filter, if_else, pull, group_by, select
#from datar.tibble import tibble
# Out:
# generated new fontManager

# %%
df = pd.read_feather("firma_data.feather")
print(df.head())
print(df.count())
# Out:
#         Date  Underlying  C435  C440  C445   C450   C455  C460   C465   C470  \
# 0 2025-09-11      470.73  None  None  <NA>   <NA>   <NA>  25.4  19.27   18.2
# 1 2025-09-12      471.31  None  None  <NA>  31.79  27.75  25.0   19.1   <NA>
# 2 2025-09-15      473.25  None  None  <NA>   <NA>   <NA>  <NA>   <NA>   18.9
# 3 2025-09-16      474.32  None  None  <NA>   <NA>   <NA>  <NA>  22.36  21.39
# 4 2025-09-17      473.12  None  None  <NA>   <NA>   <NA>  25.6   <NA>  19.35
#
#    ...  P440  P445  P450  P455   P460   P465   P470   P475  P480  P485
# 0  ...   5.1  <NA>  6.43  <NA>   <NA>  12.68   15.5   <NA>  <NA>  <NA>
# 1  ...  <NA>  6.27  <NA>  9.16   <NA>  12.85  14.95   <NA>  <NA>  <NA>
# 2  ...  <NA>   5.4   7.1  <NA>  10.32  11.85  13.95   <NA>  <NA>  <NA>
# 3  ...   4.6  <NA>  6.35  <NA>   <NA>  10.35   12.7  14.25  <NA>  <NA>
# 4  ...   4.3   5.4   6.3  7.76   <NA>   10.9   <NA>   <NA>  <NA>  <NA>
#
# [5 rows x 24 columns]
# Date          37
# Underlying    37
# C435           0
# C440           0
# C445           4
# C450           5
# C455           8
# C460          13
# C465          16
# C470          25
# C475          20
# C480          27
# C485          25
# P435          11
# P440          19
# P445          17
# P450          24
# P455          15
# P460          23
# P465          27
# P470          28
# P475          24
# P480          26
# P485          24
# dtype: int64
